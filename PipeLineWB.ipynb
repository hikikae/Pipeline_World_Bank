# %% [markdown]
# <a href="https://colab.research.google.com/github/hikikae/worldBank/blob/main/PipeLineWB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import plotly.express as px

# ------------------------        Extraction          --------------------------
def extract_api_data(indicator_code):
    try:
        url = f"http://api.worldbank.org/v2/country/all/indicator/{indicator_code}?format=json" 
        data = [] 
        response = requests.get(url)
        n = response.json()[0]['pages']#-299
        for x in range(1, n+1):
            response = requests.get(f"{url}&page={x}")   
            for item in response.json()[1]:
                data.append(item)
        return data
    except Exception as e:
        print(e)

# ---------------------------        Data Lake        --------------------------
def convert_to_dataframe(data):
    df = pd.DataFrame(data)
    #this could be the datalake
    df = df.to_json('./raw_data.json')


# ---------------------------      Data Warehouse     --------------------------
def transform_data():
    df = pd.read_json('./raw_data.json')    
    #flat json
    df= pd.concat([pd.json_normalize(df['indicator']).add_prefix('indicator.'),
                     pd.json_normalize(df['country']).add_prefix('country.'),
                     df.drop(['indicator', 'country'], axis=1)], axis=1)     
    #filling the nulls
    df['country.id'].fillna(df['countryiso3code'], inplace=True)
    df['countryiso3code'].fillna(df['country.id'], inplace=True)
    df=df[['country.value','countryiso3code','date','value']]
    df = df.rename(columns={'country.value': 'country',
                            'countryiso3code': 'country_code', 'date': 'year',
                            'value': 'population'})
    #this could be the datawarehouse
    df.to_csv('./clean_data.csv', index=False)


# ----------------------      Country Analysis  (Text)     ---------------------

def country_dataframe():
    # select only those that are countries
    df = pd.read_csv('./clean_data.csv')
    df_countries = df.iloc[3038:]
    df_countries.to_csv('./country_data.csv', index=False)

def average_population_by_years():
    df_countries=pd.read_csv('./country_data.csv')
    #average population by country over the years
    average_population = df_countries.groupby("country")["population"].mean().reset_index().sort_values(by='population', ascending=False).head(10)
    average_population['population'] = average_population[['population']].applymap('{:,.0f}'.format)
    print('average population by country over the years')
    print(average_population)
    return average_population

def population_country_2021():
    #population of each country in 2021
    df_countries=pd.read_csv('./country_data.csv')
    population_2021 = df_countries.loc[df_countries['year'] == 2021, ['year', 'country', 'population']].reset_index().sort_values(by='population', ascending=False).head(10)
    population_2021['population'] = population_2021[['population']].applymap('{:,.0f}'.format)
    print('population of each country in 2021')
    print(population_2021)
    return population_2021

def growth_percentage_country():
    #growth percentage by country over the years
    df_countries=pd.read_csv('./country_data.csv')
    df_countries_percentage = df_countries.copy()
    df_countries_percentage.loc[:,'last'] = df_countries_percentage.groupby('country')['population'].shift(1)
    df_countries_percentage['growth'] = (df_countries_percentage['population'] / df_countries_percentage['last']) - 1
    growth_percentage = (df_countries_percentage.groupby('country')['growth'].mean()*100).reset_index().rename(columns={'growth': 'percentage'}).sort_values(by='percentage', ascending=False).head(10)
    print('growth percentage by country over the years')
    print(growth_percentage)
    return(growth_percentage)

# ---------------------      Country Analysis (Plot)          ------------------
def plot_average_population_by_years(average_population):
    #average_population=average_population_by_years()
    fig = px.bar(average_population, x='country', y='population', 
             color='population', color_continuous_scale='PuBuGn',
             title='average population by country over the years')
    fig.update_layout(xaxis_title='country', yaxis_title='population',
                  font=dict(size=15, family='Franklin Gothic'),template='plotly_dark')
    fig.show()

def plot_population_2021(population_2021):
    fig = px.scatter(population_2021, x='country', y='population', 
             color='population', color_continuous_scale='PuBuGn',
             title='population of each country in 2021')
    fig.update_layout(xaxis_title='country', yaxis_title='population',
                 font=dict(size=15, family='Franklin Gothic'),template='plotly_dark')
    fig.show()

def plot_growth_percentage(growth_percentage):
    fig = px.bar(growth_percentage, x='country', y='percentage', 
             color='percentage', color_continuous_scale='PuBuGn',
             title='growth percentage by country over the years')
    fig.update_layout(xaxis_title='country', yaxis_title='percentage_growth',
                  font=dict(size=15, family='Franklin Gothic'),template='plotly_dark')
    fig.show()

# ---------------------      Country Analysis (ML)          ------------------
from sklearn.linear_model import LinearRegression

def population_estimates(country, future_year):
    df_countries=pd.read_csv('./country_data.csv')
    df_country_estimate = df_countries[df_countries['country'] == country]
    X = df_country_estimate['year'].values.reshape(-1, 1)
    y = df_country_estimate['population'].values.reshape(-1, 1)
    reg = LinearRegression().fit(X, y)
    future_population = int(reg.predict([[future_year]])[0][0])
    future_population_str = '{:,.0f}'.format(future_population)
    print(f'Projected population for {country} in {future_year}: {future_population_str}')
    return future_population
    
def main():
    indicator= 'SP.POP.TOTL'
    data= extract_api_data(indicator)
    convert_to_dataframe(data)
    transform_data()
    country_dataframe()
    average_population=average_population_by_years()
    plot_average_population_by_years(average_population)
    population_2021= population_country_2021()
    plot_population_2021(population_2021)
    growth_percentage=growth_percentage_country()
    plot_growth_percentage(growth_percentage)
    future_population = population_estimates(country='China', future_year=2023)
   

if __name__ == '__main__':
    main()
# Out:
# average population by country over the years
#                 country     population
# 41                China  1,099,373,145
# 89                India    899,719,861
# 206       United States    256,301,023
# 90            Indonesia    182,159,909
# 26               Brazil    148,560,342
# 161  Russian Federation    139,932,931
# 149            Pakistan    124,917,221
# 98                Japan    118,308,800
# 15           Bangladesh    108,516,768
# 144             Nigeria    107,223,178
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a75ba451-3725-4d5b-82e0-c6c947346559" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a75ba451-3725-4d5b-82e0-c6c947346559")) {                    Plotly.newPlot(                        "a75ba451-3725-4d5b-82e0-c6c947346559",                        [{"alignmentgroup":"True","hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"1,099,373,145","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1,099,373,145","offsetgroup":"1,099,373,145","orientation":"v","showlegend":true,"textposition":"auto","x":["China"],"xaxis":"x","y":["1,099,373,145"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"899,719,861","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"899,719,861","offsetgroup":"899,719,861","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":["899,719,861"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"256,301,023","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"256,301,023","offsetgroup":"256,301,023","orientation":"v","showlegend":true,"textposition":"auto","x":["United States"],"xaxis":"x","y":["256,301,023"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"182,159,909","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"182,159,909","offsetgroup":"182,159,909","orientation":"v","showlegend":true,"textposition":"auto","x":["Indonesia"],"xaxis":"x","y":["182,159,909"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"148,560,342","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"148,560,342","offsetgroup":"148,560,342","orientation":"v","showlegend":true,"textposition":"auto","x":["Brazil"],"xaxis":"x","y":["148,560,342"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"139,932,931","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"139,932,931","offsetgroup":"139,932,931","orientation":"v","showlegend":true,"textposition":"auto","x":["Russian Federation"],"xaxis":"x","y":["139,932,931"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"124,917,221","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"124,917,221","offsetgroup":"124,917,221","orientation":"v","showlegend":true,"textposition":"auto","x":["Pakistan"],"xaxis":"x","y":["124,917,221"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"118,308,800","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"118,308,800","offsetgroup":"118,308,800","orientation":"v","showlegend":true,"textposition":"auto","x":["Japan"],"xaxis":"x","y":["118,308,800"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"108,516,768","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"108,516,768","offsetgroup":"108,516,768","orientation":"v","showlegend":true,"textposition":"auto","x":["Bangladesh"],"xaxis":"x","y":["108,516,768"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"107,223,178","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"107,223,178","offsetgroup":"107,223,178","orientation":"v","showlegend":true,"textposition" ...
# population of each country in 2021
#      index  year             country     population
# 41    2542  2021               China  1,412,360,000
# 89    5518  2021               India  1,407,563,842
# 206  12772  2021       United States    331,893,745
# 90    5580  2021           Indonesia    273,753,191
# 149   9238  2021            Pakistan    231,402,117
# 26    1612  2021              Brazil    214,326,223
# 144   8928  2021             Nigeria    213,401,323
# 15     930  2021          Bangladesh    169,356,251
# 161   9982  2021  Russian Federation    143,449,286
# 127   7874  2021              Mexico    126,705,138
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2b933457-e36a-4903-98a9-78dcd2153c14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b933457-e36a-4903-98a9-78dcd2153c14")) {                    Plotly.newPlot(                        "2b933457-e36a-4903-98a9-78dcd2153c14",                        [{"hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"1,412,360,000","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"1,412,360,000","orientation":"v","showlegend":true,"x":["China"],"xaxis":"x","y":["1,412,360,000"],"yaxis":"y","type":"scatter"},{"hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"1,407,563,842","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"1,407,563,842","orientation":"v","showlegend":true,"x":["India"],"xaxis":"x","y":["1,407,563,842"],"yaxis":"y","type":"scatter"},{"hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"331,893,745","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"331,893,745","orientation":"v","showlegend":true,"x":["United States"],"xaxis":"x","y":["331,893,745"],"yaxis":"y","type":"scatter"},{"hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"273,753,191","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"273,753,191","orientation":"v","showlegend":true,"x":["Indonesia"],"xaxis":"x","y":["273,753,191"],"yaxis":"y","type":"scatter"},{"hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"231,402,117","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"231,402,117","orientation":"v","showlegend":true,"x":["Pakistan"],"xaxis":"x","y":["231,402,117"],"yaxis":"y","type":"scatter"},{"hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"214,326,223","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"214,326,223","orientation":"v","showlegend":true,"x":["Brazil"],"xaxis":"x","y":["214,326,223"],"yaxis":"y","type":"scatter"},{"hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"213,401,323","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"213,401,323","orientation":"v","showlegend":true,"x":["Nigeria"],"xaxis":"x","y":["213,401,323"],"yaxis":"y","type":"scatter"},{"hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"169,356,251","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"169,356,251","orientation":"v","showlegend":true,"x":["Bangladesh"],"xaxis":"x","y":["169,356,251"],"yaxis":"y","type":"scatter"},{"hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"143,449,286","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"143,449,286","orientation":"v","showlegend":true,"x":["Russian Federation"],"xaxis":"x","y":["143,449,286"],"yaxis":"y","type":"scatter"},{"hovertemplate":"population=%{y}<br>country=%{x}<extra></extra>","legendgroup":"126,705,138","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"126,705,138","orientation":"v","showlegend":true,"x":["Mexico"],"xaxis":"x","y":["126,705,138"],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolo ...
# growth percentage by country over the years
#                     country  percentage
# 181     St. Kitts and Nevis    0.292228
# 29                 Bulgaria    0.223298
# 109                  Latvia    0.199061
# 48                  Croatia    0.102979
# 87                  Hungary    0.046198
# 24   Bosnia and Herzegovina    0.014191
# 115               Lithuania   -0.007830
# 72                  Georgia   -0.020491
# 203                 Ukraine   -0.036549
# 168                  Serbia   -0.053907
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="cfe7b1ff-14b6-4526-9779-a9ab2276b360" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfe7b1ff-14b6-4526-9779-a9ab2276b360")) {                    Plotly.newPlot(                        "cfe7b1ff-14b6-4526-9779-a9ab2276b360",                        [{"alignmentgroup":"True","hovertemplate":"country=%{x}<br>percentage=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.29222755586540206,0.22329838596068435,0.19906054022879222,0.1029788664073508,0.046198308894933156,0.014190514674662532,-0.007829819307198586,-0.020490629120244935,-0.03654922295262805,-0.05390662700642957],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["St. Kitts and Nevis","Bulgaria","Latvia","Croatia","Hungary","Bosnia and Herzegovina","Lithuania","Georgia","Ukraine","Serbia"],"xaxis":"x","y":[0.29222755586540206,0.22329838596068435,0.19906054022879222,0.1029788664073508,0.046198308894933156,0.014190514674662532,-0.007829819307198586,-0.020490629120244935,-0.03654922295262805,-0.05390662700642957],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66 ...
# Projected population for China in 2023: 1,521,024,389
